# %% [markdown]
# # Visualisierung der Daten

# %%
from visualization_utils import *

# %% [markdown]
# ## Aktienkurse mit LSTM

# %% [markdown]
# ### Loss

# %%
DIR_NAME_LOSS_STOCK = 'Stock_losses'
clip_norms = [None, 0.1]
learning_rates = [0.01, 0.05, 0.1]
N_EPOCHS = 32
LEGEND_LOCATION = 'lower left'
plot_training_loss_histories(
    dir_name=DIR_NAME_LOSS_STOCK,
    clip_norms=clip_norms,
    learning_rates=learning_rates,
    epochs=N_EPOCHS,
    loc=LEGEND_LOCATION)

# %% [markdown]
# ### Glattheit

# %%
DIR_NAME_SMOOTHNESS_STOCK='Stock_smoothness'
lot_estimates_smoothness(DIR_NAME_SMOOTHNESS_STOCK, clip_norms, learning_rates)

# %% [markdown]
# ## Bilderkennung

# %% [markdown]
# ### Loss

# %%
DIR_NAME_LOSS_CIFAR = 'Cifar10_losses'
clip_norms = [None, 0.25]
learning_rates = [0.1, 0.25, 0.5]
N_EPOCHS = 64
LEGEND_LOCATION = 'lower left'
plot_training_loss_histories(
    dir_name=DIR_NAME_LOSS_CIFAR,
    clip_norms=clip_norms,
    learning_rates=learning_rates,
    epochs=N_EPOCHS,
    loc=LEGEND_LOCATION)

# %% [markdown]
# ### Glattheit

# %%
DIR_NAME_SMOOTHNESS_CIFAR='Cifar10_smoothness'
plot_estimates_smoothness(DIR_NAME_SMOOTHNESS_CIFAR, [None, 0.5], [0.05, 0.1, 0.25])

# %% [markdown]
# ## Film Rezessionen

# %% [markdown]
# ### Loss

# %%
DIR_NAME_LOSS_CIFAR = 'Movie_review_losses'
clip_norms = [None, 0.5, 5]
learning_rates = [0.1, 0.25, 0.5, 0.75, 1]
N_EPOCHS = 64
LEGEND_LOCATION = 'lower left'
plot_training_loss_histories(
    dir_name=DIR_NAME_LOSS_CIFAR,
    clip_norms=clip_norms,
    learning_rates=learning_rates,
    epochs=N_EPOCHS,
    loc=LEGEND_LOCATION)

# %% [markdown]
# ### Glattheit

# %%
DIR_NAME_SMOOTHNESS_CIFAR='movie_review_smoothness'
plot_estimates_smoothness(DIR_NAME_SMOOTHNESS_CIFAR, [None, 0.5, 5], [0.1, 0.25, 0.5, 0.75, 1])
